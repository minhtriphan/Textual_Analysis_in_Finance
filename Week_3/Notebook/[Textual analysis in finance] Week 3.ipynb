# %% [markdown]
# # Defining global variables

# %%
REPO_NAME = 'Textual_Analysis_in_Finance'
BASE_DIR = f'/kaggle/working/{REPO_NAME}'
WEEK = 3

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Clone the lecture's git repo

# %%
# !git clone https://github.com/minhtriphan/{REPO_NAME}.git
# %cd {REPO_NAME}
# Out:
# Cloning into 'Textual_Analysis_in_Finance'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 201 (delta 61), reused 153 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (201/201), 7.71 MiB | 15.75 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# /kaggle/working/Textual_Analysis_in_Finance

# %% [markdown]
# # Exploring the Google pre-trained Word2Vec model
#
# Many organizations/people train their Word2Vec models and published them. Those models are called _pre-trained models_.
#
# One of the most popular pre-trained models is the Word2Vec model trained by Google using their Google News dataset.
#
# The model is trained on the data containing approximately 100 billion words, generated from 3 million unique words (i.e., the vocab size). Each word is represented by a 300-dimensional vector.
#
# We can obtain the model using `gensim`. However, first, we need to add the model as our notebook input.
#
# The model can be found [**here**](https://www.kaggle.com/datasets/sugataghosh/google-word2vec). To use it, follow the below steps:
#
# 1. On the right-hand side tab, click on `+ Add Input` button in the `Input` tab
# 2. On the search bar, input the URL: https://www.kaggle.com/datasets/sugataghosh/google-word2vec
# 3. The model is uploaded in the first search result, named `Google Word2Vec`
# 4. You will see a plus sign with a circle symbol next to the search result, click on it, and wait
# 5. Kaggle will inform you when the model is added successfully
#
# To use the model, we need to import the `KeyedVectors` class from `gensim`

# %%
from gensim.models import KeyedVectors

GOOGLE_WORD2VEC_PATH = '/kaggle/input/datasets/sugataghosh/google-word2vec/GoogleNews-vectors-negative300.bin'
google_wv = KeyedVectors.load_word2vec_format(GOOGLE_WORD2VEC_PATH, binary = True)

# %% [markdown]
# #### Check the vocabulary size

# %%
len(google_wv)
# Out:
# 3000000

# %% [markdown]
# #### Check the vector size/dimensions

# %%
google_wv.vector_size
# Out:
# 300

# %% [markdown]
# #### What are words in the vocabulary

# %%
list(google_wv.key_to_index.keys())[:10]    # Just print the first 10 words in the vocabulary
# Out:
# ['</s>', 'in', 'for', 'that', 'is', 'on', '##', 'The', 'with', 'said']

# %% [markdown]
# #### Let check the vector of a word

# %%
google_wv['profit']
# Out:
# array([-1.49414062e-01, -1.19628906e-01, -1.47460938e-01,  1.68945312e-01,
#        -2.14843750e-01, -3.45703125e-01,  1.55029297e-02, -5.54199219e-02,
#         2.92968750e-01,  1.41601562e-01, -2.63671875e-01,  1.38671875e-01,
#         1.77734375e-01,  1.06933594e-01, -3.28125000e-01,  1.15234375e-01,
#        -1.17675781e-01, -8.48388672e-03,  3.02734375e-01, -4.51660156e-02,
#         3.71093750e-02,  6.98242188e-02, -8.39843750e-02, -2.57812500e-01,
#         9.86328125e-02,  1.58203125e-01, -1.05468750e-01,  3.56445312e-02,
#        -1.22558594e-01, -2.37304688e-01, -7.37304688e-02,  1.36108398e-02,
#        -2.13867188e-01, -1.01074219e-01, -3.93066406e-02,  1.51367188e-01,
#        -1.93359375e-01,  3.73535156e-02, -2.70996094e-02,  2.77343750e-01,
#         2.77343750e-01, -2.27355957e-03,  2.18750000e-01,  8.30078125e-02,
#        -5.68847656e-02, -3.24218750e-01,  4.00390625e-02,  2.67578125e-01,
# ...

# %% [markdown]
# #### Let's check the most similar words of a word

# %%
google_wv.most_similar('profit', topn = 5)
# Out:
# [('profits', 0.802002489566803),
#  ('proft', 0.7426661252975464),
#  ('pretax_profit', 0.6691470742225647),
#  ('pretax_profits', 0.643925130367279),
#  ('Profit', 0.6339423060417175)]

# %% [markdown]
# #### We can also compute the similarity between 2 words

# %%
google_wv.similarity('loss', 'profit')
# Out:
# np.float32(0.34199455)

# %% [markdown]
# #### Check which word is most different from the others

# %%
google_wv.doesnt_match(['stock', 'volume', 'returns', 'liquidity', 'volleyball', 'market'])
# Out:
# 'volleyball'

# %% [markdown]
# #### Derive the vector for the whole sentence
#
# Let's say we have a sentence (after cleaning): `income increase`, we can find the vector of this sentence by averaging the vectors of component words. Technically, if
#
# * `income` $\rightarrow$ $v_1$
# * `increase` $\rightarrow$ $v_2$
#
# `income increase` $\rightarrow$ $\frac{1}{2}(v_1 + v_2)$

# %%
import numpy as np

sentence = 'income increase'

sentence_vector = []

for word in sentence.split():
    sentence_vector.append(google_wv[word])
    
sentence_vector = np.mean(sentence_vector, axis = 0)
sentence_vector
# Out:
# array([ 0.04858398, -0.11425781, -0.18554688,  0.1116333 , -0.05456543,
#        -0.1274414 , -0.00976562, -0.17041016,  0.15576172,  0.10290527,
#        -0.05328369,  0.08605957, -0.00817871,  0.1385498 , -0.10205078,
#         0.03076172, -0.01367188,  0.01147461,  0.08251953,  0.04048157,
#        -0.10400391, -0.0246582 ,  0.01342773, -0.23242188, -0.10910034,
#         0.01928711, -0.01901245,  0.08728027, -0.17675781,  0.07421875,
#         0.02886963, -0.2998047 ,  0.10449219, -0.19140625,  0.00146484,
#        -0.05004883, -0.02111816,  0.02294922, -0.08007812,  0.29882812,
#         0.1772461 ,  0.19970703,  0.14892578, -0.0065918 , -0.25976562,
#        -0.36816406,  0.07009888,  0.18701172, -0.20629883,  0.05224609,
#         0.15966797, -0.17333984, -0.0748291 , -0.09594727,  0.0604248 ,
#        -0.07678223, -0.21533203, -0.00244141,  0.01184082, -0.07794189,
#         0.05712891, -0.03617859, -0.26660156, -0.02450562,  0.23876953,
# ...

# %% [markdown]
# # Training a Word2Vec model using Tesla's 10-K files from 2020 to 2025

# %%
import os
from glob import glob

all_10k_files = glob(os.path.join(BASE_DIR, 'Data', 'FinancialStatements', '*.txt'))
all_10k_files
# Out:
# ['/kaggle/working/Textual_Analysis_in_Finance/Data/FinancialStatements/20190219_10-K_edgar_data_1318605_0001564590-19-003165.txt',
#  '/kaggle/working/Textual_Analysis_in_Finance/Data/FinancialStatements/20220207_10-K_edgar_data_1318605_0000950170-22-000796.txt',
#  '/kaggle/working/Textual_Analysis_in_Finance/Data/FinancialStatements/20240129_10-K_edgar_data_1318605_0001628280-24-002390.txt',
#  '/kaggle/working/Textual_Analysis_in_Finance/Data/FinancialStatements/20200213_10-K_edgar_data_1318605_0001564590-20-004475.txt',
#  '/kaggle/working/Textual_Analysis_in_Finance/Data/FinancialStatements/20160224_10-K_edgar_data_1318605_0001564590-16-013195.txt',
#  '/kaggle/working/Textual_Analysis_in_Finance/Data/FinancialStatements/20230131_10-K_edgar_data_1318605_0000950170-23-001409.txt',
#  '/kaggle/working/Textual_Analysis_in_Finance/Data/FinancialStatements/20170301_10-K_edgar_data_1318605_0001564590-17-003118.txt',
# ...

# %% [markdown]
# #### <span style="color:red">Questions</span>
#
# 1. Can you explain the file name? E.g., `20250130_10-K_edgar_data_1318605_0001628280-25-003063.txt`

# %% [markdown]
# #### Let's try to check one 10-K document

# %%
with open(all_10k_files[0], 'r') as f:
    content = f.read()
content[:5_000]
# Out:
# '<Header>\n<FileStats>\n    <FileName>20190219_10-K_edgar_data_1318605_0001564590-19-003165.txt</FileName>\n    <GrossFileSize>30826751</GrossFileSize>\n    <NetFileSize>1252190</NetFileSize>\n    <NonText_DocumentType_Chars>950794</NonText_DocumentType_Chars>\n    <HTML_Chars>14509273</HTML_Chars>\n    <XBRL_Chars>7649938</XBRL_Chars>\n    <XML_Chars>5759995</XML_Chars>\n    <N_Exhibits>15</N_Exhibits>\n</FileStats>\n<SEC-Header>\n0001564590-19-003165.hdr.sgml : 20190219\n<ACCEPTANCE-DATETIME>20190219061016\nACCESSION NUMBER:\t\t0001564590-19-003165\nCONFORMED SUBMISSION TYPE:\t10-K\nPUBLIC DOCUMENT COUNT:\t\t162\nCONFORMED PERIOD OF REPORT:\t20181231\nFILED AS OF DATE:\t\t20190219\nDATE AS OF CHANGE:\t\t20190219\n\nFILER:\n\n\tCOMPANY DATA:\t\n\t\tCOMPANY CONFORMED NAME:\t\t\tTesla, Inc.\n\t\tCENTRAL INDEX KEY:\t\t\t0001318605\n\t\tSTANDARD INDUSTRIAL CLASSIFICATION:\tMOTOR VEHICLES & PASSENGER CAR BODIES [3711]\n\t\tIRS NUMBER:\t\t\t\t912197729\n\t\tSTATE OF INCORPORATION:\t\t\tDE
# ...

# %% [markdown]
# #### <span style="color:red">Questions</span>
#
# 2. Assume words are those separated by a space ' '. Check how many words are there in the above 10-K?
# 3. Assume paragraphs are those separated by a double line break '\n\n'. Check how many paragraphs are there in the above 10-K?

# %% [markdown]
# ## Read and clean the data

# %%
from tqdm.auto import tqdm
from Week_1.Code.Utils import readfile, lowercase, special_character_removal, fix_contraction, stopword_removal, lemmatization

# The text-normalization function
def text_normalization(f):
    text = readfile(f)
    text = lowercase(text)
    text = fix_contraction(text)
    text = special_character_removal(text, keep = '.', remove_number = True)
    text = stopword_removal(text, remove_single_letters = True)
    text = lemmatization(text[:1_000_000])
    return text

# Read, then clean all 10-K files of Tesla
contents = []
for f in tqdm(all_10k_files):
    contents.append(text_normalization(f))
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 5.4 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ## Let's train a Word2Vec model using those clean texts
#
# This can be done using the `gensim` package. First, let's import it by `from gensim.models import Word2Vec`.
#
# An example usage is as follows,
#
# ```
# model = Word2Vec(
#     sentences = corpus      # Your tokenized corpus
#     vector_size = 100,      # Dimensionality of the word vectors
#     window = 5,             # Context window size
#     min_count = 2,          # Ignore words with total frequency < 2
#     workers = 4,            # Number of CPU cores to use
#     epochs = 5,             # Number of iterations the model goes over the corpus
#     sg = 1                  # 1 for Skip-gram; 0 for CBOW
#
# )
# ```

# %% [markdown]
# #### 1. Prepare the corpus
#
# The `corpus` argument should look like
#
# ```
# corpus = [
#     ['word_1,1', 'word_1,2', ..., 'word_1,1t'],
#     ['word_2,1', 'word_2,2', ..., 'word_2,2t'],
#     ...,
#     ['word_N,1', 'word_N,2', ..., 'word_N,Nt'],
# ]
# ```
#
# With our data, `contents` contains 10-K files. We try to split each of them into sentences first.

# %%
from nltk import sent_tokenize

corpus = []

for content in tqdm(contents):
    sentences = sent_tokenize(content)
    corpus.extend(sentences)    # NOTICE: use .extend() here instead of .append()

print(f'There are {len(corpus)} sentences in the whole corpus')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# There are 45524 sentences in the whole corpus

# %% [markdown]
# After that, we have to tokenize sentences

# %%
from nltk import word_tokenize

tokenized_corpus = []

for sent in tqdm(corpus):
    tokenized_corpus.append(word_tokenize(sent))
# Out:
#   0%|          | 0/45524 [00:00<?, ?it/s]

# %% [markdown]
# #### Training

# %%
from gensim.models import Word2Vec

word2vec_model = Word2Vec(
    sentences = tokenized_corpus,    # Put the prepared corpus here
    vector_size = 100,
    window = 5,
    min_count = 2,
    workers = 4,
    sg = 1,
    epochs = 30
)

# %% [markdown]
# ## Evaluating the results

# %% [markdown]
# * First, check the vocabulary

# %%
print(f'There are {len(word2vec_model.wv)} words in the vocabulary')
# Out:
# There are 6144 words in the vocabulary

# %% [markdown]
# * Check the vector of a single words

# %%
word = 'profit'
if word in word2vec_model.wv.key_to_index:
    print(f'The embedding of "{word}" is:')
    print(word2vec_model.wv['profit'])
else:
    print('Your chosen word does not appear in the vocabulary, please choose another word!')
# Out:
# The embedding of "profit" is:
# [ 1.3122381e-01 -1.3910659e-02  1.5304980e+00  2.0142679e-01
#  -1.2388381e-01  3.2836673e-01  5.2077603e-02  6.9054484e-01
#   3.0024019e-01 -8.1651318e-01  2.0206656e-02 -1.4230432e-01
#   2.9148734e-01  2.2509664e-01 -7.1315145e-01 -6.9250202e-01
#   1.4033467e-01 -5.9634143e-01  5.0031212e-03 -7.0825464e-01
#   1.6539425e-01 -2.5501275e-01  7.5807238e-01  2.0463352e-01
#  -1.2828903e-01 -1.0527604e-01  7.0303726e-01  3.3991846e-01
#  -4.2406133e-01 -4.4658256e-01  5.3542274e-01  5.4573071e-01
#   6.6446698e-01 -1.2777992e-01  7.3877163e-02  6.3176870e-01
#  -9.6697968e-01 -1.5546665e-01 -7.5135553e-01 -1.2569752e+00
#   1.2568527e-01  1.6591135e-02 -1.7106752e-01 -1.4394552e-01
#  -2.2111161e-01 -1.1548730e-01 -3.2055405e-01  1.1831973e+00
#   7.7808633e-02  1.3559140e+00  1.1268064e+00  2.9577371e-01
#  -2.8503612e-01  1.6828890e-01  9.8756909e-02 -6.0843956e-02
#  -5.1637888e-01 -4.3638992e-01  4.5600528e-01  9.9686092e-01
# ...

# %%
word2vec_model.wv.most_similar('profit')
# Out:
# [('shifting', 0.6880323886871338),
#  ('gross', 0.6320213675498962),
#  ('erosion', 0.6092595458030701),
#  ('denominated', 0.5652006268501282),
#  ('revenues', 0.562018632888794),
#  ('imprisonment', 0.5614103078842163),
#  ('segment', 0.5434383749961853),
#  ('margin', 0.532157838344574),
#  ('turnover', 0.5297002196311951),
#  ('substantive', 0.5278282165527344)]

# %% [markdown]
# #### <span style="color:red">Questions</span>
#
# 2. Evaluate the result, what do you think about our own Word2Vec model?

# %% [markdown]
# ## Fine-tuning a Word2Vec model
#
# We can adapt the pre-trained Google Word2Vec model to our data (i.e., the Tesla's 10-K filings)
#
# This method is called **fine-tuning**. For Word2Vec, it can be done using the following steps
#
# 1. Create a new Word2Vec model with same dimensions

# %%
finetuned_word2vec_model = Word2Vec(
    vector_size = google_wv.vector_size, 
    min_count = 2,
    sg = 1
)

# %% [markdown]
# 2. Build the vocabulary using our data, which is `tokenized_corpus`

# %%
finetuned_word2vec_model.build_vocab(tokenized_corpus)

# %% [markdown]
# 3. (**Important**) Inject the pre-trained word vectors, which is `google_wv` in our case

# %%
finetuned_word2vec_model.wv.vectors_lockf = np.ones(len(google_wv))    # Enable training
finetuned_word2vec_model.wv.intersect_word2vec_format('/kaggle/input/datasets/sugataghosh/google-word2vec/GoogleNews-vectors-negative300.bin', binary = True)

# %% [markdown]
# 4. Train the model

# %%
finetuned_word2vec_model.train(tokenized_corpus, total_examples = len(tokenized_corpus), epochs = 5)
# Out:
# (3092966, 3521430)

# %% [markdown]
# #### Evaluate the fine-tuned model

# %% [markdown]
# * The fine-tuned model, combining the knowledge of the Google Word2Vec model and our specific data

# %%
finetuned_word2vec_model.wv.most_similar('profit', topn = 5)
# Out:
# [('revenue', 0.5829346179962158),
#  ('pretax', 0.5686764717102051),
#  ('quarterly', 0.5639331936836243),
#  ('revenues', 0.5549612641334534),
#  ('income', 0.5063909888267517)]

# %%
google_wv.most_similar('profit', topn = 5)
# Out:
# [('profits', 0.802002489566803),
#  ('proft', 0.7426661252975464),
#  ('pretax_profit', 0.6691470742225647),
#  ('pretax_profits', 0.643925130367279),
#  ('Profit', 0.6339423060417175)]

# %%
word2vec_model.wv.most_similar('profit', topn = 5)
# Out:
# [('shifting', 0.6880323886871338),
#  ('gross', 0.6320213675498962),
#  ('erosion', 0.6092595458030701),
#  ('denominated', 0.5652006268501282),
#  ('revenues', 0.562018632888794)]

# %% [markdown]
# # Training a Doc2Vec model
#
# To train a Doc2Vec model, we need to prepare the documents, which is more complicated than Word2Vec.
#
# Training a Doc2Vec model includes the following steps:
#
# 1. Prepare the corpus (documents) to have the following form
# ```
# corpus = [
#     ['word_1,1', 'word_1,2', ..., 'word_1,1t'],
#     ['word_2,1', 'word_2,2', ..., 'word_2,2t'],
#     ...,
#     ['word_N,1', 'word_N,2', ..., 'word_N,Nt'],
# ]
# ```
#
# This is our `tokenized_corpus` as above
#
# 2. Tag the document using the `TaggedDocument` method as follows:
#
# ```
# from gensim.models.doc2vec import TaggedDocument
#
# tagged_documents = [TaggedDocument(words = words, tags = [str(i)]) for i, words in enumerate(corpus)]
# ```
#
# 3. Initialize the model
#
# ```
# model = Doc2Vec(
#     vector_size = 100,   # Dimensionality of the word vectors
#     window = 5,          # Context window size
#     min_count = 2,       # Ignore words with total frequency < 2
#     workers = 4,         # Number of CPU cores to use in parallel
#     epochs = 40,         # Number of iterations the model goes over the corpus
#     dm = 1               # 1 for Distributed Memory; 0 for DBOW
# )
# ```
#
# 4. Build the vocabulary
#
# ```
# model.build_vocab(tagged_documents)
# ```
#
# 5. Train
#
# ```
# model.train(tagged_docs)
# ```
#
# **Let's put everything together!**

# %% [markdown]
# ## Train a Doc2Vec model

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

tagged_documents = [TaggedDocument(words = words, tags = [str(i)]) for i, words in enumerate(tokenized_corpus)]

doc2vec_model = Doc2Vec(
    vector_size = 100,
    window = 5,
    min_count = 2,
    workers = 4,
    epochs = 40,
    dm = 0
)

doc2vec_model.build_vocab(tagged_documents)

doc2vec_model.train(tagged_documents, total_examples = doc2vec_model.corpus_count, epochs = doc2vec_model.epochs)

# %% [markdown]
# If you want to save the model for later use, type `model.save(os.path.join('<path_to_output>', 'doc2vec.model'))`.
#
# To load a saved model, type `model = Doc2Vec.load(os.path.join('<path_to_output>', 'doc2vec.model'))`

# %% [markdown]
# ## Post-training, infer the vector of a document
#
# After training a Doc2Vec model, we will use it to infer document embedding using the `model.infer_vector` method. This method takes a **tokenized document as the input**.
#
# An example for a sample text is:

# %%
sample_text = tokenized_corpus[100]
print('The sample text is:\n', ' '.join(sample_text))
sentence_vector = doc2vec_model.infer_vector(sample_text)

top_similar_sentences = doc2vec_model.dv.most_similar([sentence_vector], topn = 5)
top_similar_sentences
# Out:
# The sample text is:
#  model model third generation electric vehicle begin deliver july .
# [('100', 0.9514783024787903),
#  ('37587', 0.8417294025421143),
#  ('24712', 0.7883352637290955),
#  ('23827', 0.7692674994468689),
#  ('17453', 0.7361563444137573)]

# %%
tagged_documents[int(top_similar_sentences[0][0])]
# Out:
# TaggedDocument(words=['model', 'model', 'third', 'generation', 'electric', 'vehicle', 'begin', 'deliver', 'july', '.'], tags=['100'])

# %% [markdown]
# ## Fine-tuning a Doc2Vec model
#
# We can also fine-tune a Doc2Vec model as we did with Word2Vec. However, we can only initialize the word vectors

# %%
finetuned_doc2vec_model = Doc2Vec(
    vector_size = google_wv.vector_size,
    window = 5,
    min_count = 2,
    workers = 4,
    dm = 0
)

finetuned_doc2vec_model.build_vocab(tagged_documents)

finetuned_doc2vec_model.wv.vectors_lockf = np.ones(len(finetuned_doc2vec_model.wv))
finetuned_doc2vec_model.wv.intersect_word2vec_format('/kaggle/input/datasets/sugataghosh/google-word2vec/GoogleNews-vectors-negative300.bin', binary = True)

finetuned_doc2vec_model.train(tagged_documents, total_examples = len(tagged_documents), epochs = 5)

# %%
sample_text = tokenized_corpus[100]
print('The sample text is:\n', ' '.join(sample_text))
sentence_vector = finetuned_doc2vec_model.infer_vector(sample_text)

top_similar_sentences = finetuned_doc2vec_model.dv.most_similar([sentence_vector], topn = 5)
top_similar_sentences
# Out:
# The sample text is:
#  model model third generation electric vehicle begin deliver july .
# [('38185', 0.9947308301925659),
#  ('7635', 0.9945164322853088),
#  ('43520', 0.9944477677345276),
#  ('37906', 0.993761420249939),
#  ('43568', 0.9929839372634888)]

# %%
' '.join(tokenized_corpus[int(top_similar_sentences[0][0])])
# Out:
# 'limited warranty battery drive unit new model model vehicle cover drive unit eight year well battery period eight year certain old vehicle mile reach soon eight year although battery charging capacity cover warranty extend service plan limited warranty use model model vehicle extend otherwise alter term original battery drive unit limited warranty use vehicle specify original new vehicle limited warranty .'

# %% [markdown]
# # ELMo
#
# Coding ELMo requires some advanced knowledge about Pytorch, including dataset and dataloader design, neural network construction. So, I decide to only provide the code as reference. Feel free to check the code to train an ELMo model in `Week_3.Code.ELMo` in the lecture's Github repo.
